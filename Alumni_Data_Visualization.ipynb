# %% [markdown]
# # Data Visualization Project
# ## Idea 1: 15 Years of BITS Hyderabad
# ### Members:
# Ashutosh Wagh (2022H1030052H)<br>
# Shivam Rajput (2022H1030058H)<br>
# S Shashank (2022H1030067H)<br>
# Ajinkya Medhekar (2022H1030099H)

# %% [markdown]
# # Data Acquisition

# %%
import pandas as pd
import random

file_path = './Student_Data/student_data_2023.csv' #change the year in the file name as required
df = pd.read_csv(file_path)


fourth_year_students = df[df['Year'] == 4]


placement_companies = {
    'Computer Science and Information Systems': {
    'Amazon': random.uniform(0.0, 0.7),
    'AMD': random.uniform(0.0, 0.7),
    'Cisco': random.uniform(0.0, 0.7),
    'Mediatek': random.uniform(0.0, 0.7),
    'Dell': random.uniform(0.0, 0.7),
    'Qualcomm': random.uniform(0.0, 0.7),
    'Flipkart': random.uniform(0.0, 0.7),
    'Intel': random.uniform(0.0, 0.7),
    'Microsoft': random.uniform(0.0, 0.7),
    'Piramal': random.uniform(0.0, 0.7),
    'Pharmo Solutions': random.uniform(0.0, 0.7),
    'Teradata': random.uniform(0.0, 0.7),
    'BLEND360': random.uniform(0.0, 0.7),
    'CONFLUENT': random.uniform(0.0, 0.7),
    'Mashreq': random.uniform(0.0, 0.7),
    'GE HealthCare': random.uniform(0.0, 0.7),
    'Google': random.uniform(0.0, 0.7),
    'IBM': random.uniform(0.0, 0.7),
    'MathWorks': random.uniform(0.0, 0.7),
    'Trilogy': random.uniform(0.0, 0.7),
    'CONCR': random.uniform(0.0, 0.7),
    'Samsung': random.uniform(0.0, 0.7),
    'VISA': random.uniform(0.0, 0.7),
    'PayU': random.uniform(0.0, 0.7),
    'Secureworks': random.uniform(0.0, 0.7),
    'VMware': random.uniform(0.0, 0.7),
    'PEGA': random.uniform(0.0, 0.7),
    'Tenstorrent': random.uniform(0.0, 0.7),
    'Western Digital': random.uniform(0.0, 0.7),
    'Micron': random.uniform(0.0, 0.7),
    'Wabtec': random.uniform(0.0, 0.7),
    'Axtria': random.uniform(0.0, 0.7),
    'Texas Instruments': random.uniform(0.0, 0.7),
    'Infineon': random.uniform(0.0, 0.7),
    'Commvault': random.uniform(0.0, 0.7),
    'Rizzle': random.uniform(0.0, 0.7),
    'ARM': random.uniform(0.0, 0.7)
}
,
    'Mechanical Engineering': {
        'ARUP': random.uniform(0.0, 0.7),
'Infineon': random.uniform(0.0, 0.7),
'SONA COMSTAR': random.uniform(0.0, 0.7),
'ANAND': random.uniform(0.0, 0.7),
'CYNLR': random.uniform(0.0, 0.7),
'DOVER': random.uniform(0.0, 0.7),
'FORVIA': random.uniform(0.0, 0.7),
'Faurecia': random.uniform(0.0, 0.7),
'JK Fenner': random.uniform(0.0, 0.7),
'Lime': random.uniform(0.0, 0.7),
'Micron': random.uniform(0.0, 0.7),
'Mercedes Benz': random.uniform(0.0, 0.7),
'SEDEMAC': random.uniform(0.0, 0.7),
'3SC': random.uniform(0.0, 0.7),
'Oeing Lie': random.uniform(0.0, 0.7),
'TATA': random.uniform(0.0, 0.7),
'Wabtec': random.uniform(0.0, 0.7),
'General Electric (GE)': random.uniform(0.0, 0.7),
'Bosch': random.uniform(0.0, 0.7),
'Lockheed Martin': random.uniform(0.0, 0.7),
'Caterpillar Inc.': random.uniform(0.0, 0.7),
'Boeing': random.uniform(0.0, 0.7),
'Ford Motor Company': random.uniform(0.0, 0.7),
'Siemens': random.uniform(0.0, 0.7),
'General Motors': random.uniform(0.0, 0.7),
'Johnson Controls': random.uniform(0.0, 0.7),
'Procter & Gamble': random.uniform(0.0, 0.7),
'Shell': random.uniform(0.0, 0.7),
'ExxonMobil': random.uniform(0.0, 0.7),
'Toyota': random.uniform(0.0, 0.7),
'Honda': random.uniform(0.0, 0.7),
'Rolls-Royce': random.uniform(0.0, 0.7),
'SpaceX': random.uniform(0.0, 0.7),
'Lockheed Martin': random.uniform(0.0, 0.7),
'ABB': random.uniform(0.0, 0.7),
'Cummins Inc.': random.uniform(0.0, 0.7)

    },
    'Mathematics': {
        'Amazon': random.uniform(0.0, 0.7),
'AMD': random.uniform(0.0, 0.7),
'Cisco': random.uniform(0.0, 0.7),
'Mediatek': random.uniform(0.0, 0.7),
'Dell': random.uniform(0.0, 0.7),
'Qualcomm': random.uniform(0.0, 0.7),
'Flipkart': random.uniform(0.0, 0.7),
'Intel': random.uniform(0.0, 0.7),
'Microsoft': random.uniform(0.0, 0.7),
'Piramal': random.uniform(0.0, 0.7),
'Pharmo Solutions': random.uniform(0.0, 0.7),
'Teradata': random.uniform(0.0, 0.7),
'BLEND360': random.uniform(0.0, 0.7),
'Google': random.uniform(0.0, 0.7),
'IBM': random.uniform(0.0, 0.7),
'MathWorks': random.uniform(0.0, 0.7),
'Trilogy': random.uniform(0.0, 0.7)

    },
    'Biological Sciences': {
        'Aragen': random.uniform(0.0, 0.7),
'Cipla': random.uniform(0.0, 0.7),
'FRESENIUS': random.uniform(0.0, 0.7),
'КАВІ': random.uniform(0.0, 0.7),
'DataZymes': random.uniform(0.0, 0.7),
'Pfizer': random.uniform(0.0, 0.7),
'Strand': random.uniform(0.0, 0.7),
'PEISION MEDICINE SOLUTIONS': random.uniform(0.0, 0.7),
'SII': random.uniform(0.0, 0.7),
'Zydus': random.uniform(0.0, 0.7),
'Sun Pharmaceutical Industries': random.uniform(0.0, 0.7),
'Dr. Reddys Laboratories': random.uniform(0.0, 0.7),
'Lupin Limited': random.uniform(0.0, 0.7),
'Cipla': random.uniform(0.0, 0.7),
'Biocon': random.uniform(0.0, 0.7),
'Cadila Healthcare': random.uniform(0.0, 0.7),
'Glenmark Pharmaceuticals': random.uniform(0.0, 0.7),
'Torrent Pharmaceuticals': random.uniform(0.0, 0.7),
'Divis Laboratories': random.uniform(0.0, 0.7),
'Alembic Pharmaceuticals': random.uniform(0.0, 0.7),
'Ipca Laboratories': random.uniform(0.0, 0.7),
'Wockhardt': random.uniform(0.0, 0.7),
'Alkem Laboratories': random.uniform(0.0, 0.7),
'Natco Pharma': random.uniform(0.0, 0.7),
'Granules India': random.uniform(0.0, 0.7),
'Aurobindo Pharma': random.uniform(0.0, 0.7),
'Emcure Pharmaceuticals': random.uniform(0.0, 0.7),
'Zydus Cadila': random.uniform(0.0, 0.7),
'Abbott Laboratories': random.uniform(0.0, 0.7),
'Novartis': random.uniform(0.0, 0.7),
'GSK Pharmaceuticals': random.uniform(0.0, 0.7),
'AstraZeneca': random.uniform(0.0, 0.7)

    },
    'Electrical and Electronics Engineering': {
       'AMDET': random.uniform(0.0, 0.7),
'CISCO': random.uniform(0.0, 0.7),
'Intel': random.uniform(0.0, 0.7),
'MathWorks': random.uniform(0.0, 0.7),
'SILICON LABS': random.uniform(0.0, 0.7),
'IBM': random.uniform(0.0, 0.7),
'MEDIATEK': random.uniform(0.0, 0.7),
'onsemi': random.uniform(0.0, 0.7),
'SynOPSYS': random.uniform(0.0, 0.7),
'MICROCHIP': random.uniform(0.0, 0.7),
'Qualcomm': random.uniform(0.0, 0.7),
'proteanTecs': random.uniform(0.0, 0.7),
'Infineon': random.uniform(0.0, 0.7),
'Micron': random.uniform(0.0, 0.7),
'INSTRUMENTS': random.uniform(0.0, 0.7),
'NXP Semiconductors': random.uniform(0.0, 0.7),
'STMicroelectronics': random.uniform(0.0, 0.7),
'Texas Instruments': random.uniform(0.0, 0.7),
'Panasonic': random.uniform(0.0, 0.7),
'Sony': random.uniform(0.0, 0.7),
'LG Electronics': random.uniform(0.0, 0.7),
'Honeywell': random.uniform(0.0, 0.7),
'Toshiba': random.uniform(0.0, 0.7),
'Renesas Electronics': random.uniform(0.0, 0.7),
'Hitachi': random.uniform(0.0, 0.7),
'Siemens': random.uniform(0.0, 0.7),
'NEC Corporation': random.uniform(0.0, 0.7),
'ON Semiconductor': random.uniform(0.0, 0.7),
'Analog Devices': random.uniform(0.0, 0.7),
'Cypress Semiconductor': random.uniform(0.0, 0.7),
'Ricoh': random.uniform(0.0, 0.7),
'Fujitsu': random.uniform(0.0, 0.7),
'Altera': random.uniform(0.0, 0.7),
'Xilinx': random.uniform(0.0, 0.7),
'Microsemi': random.uniform(0.0, 0.7)

    },
    'Physics': {
        'AMDET': random.uniform(0.0, 0.7),
'CISCO': random.uniform(0.0, 0.7),
'Intel': random.uniform(0.0, 0.7),
'MathWorks': random.uniform(0.0, 0.7),
'SILICON LABS': random.uniform(0.0, 0.7),
'IBM': random.uniform(0.0, 0.7),
'MEDIATEK': random.uniform(0.0, 0.7),
'onsemi': random.uniform(0.0, 0.7),
'SynOPSYS': random.uniform(0.0, 0.7),
'MICROCHIP': random.uniform(0.0, 0.7),
'Qualcomm': random.uniform(0.0, 0.7),
'proteanTecs': random.uniform(0.0, 0.7),
'Infineon': random.uniform(0.0, 0.7),
'Micron': random.uniform(0.0, 0.7),
'SAMSUNG': random.uniform(0.0, 0.7),
'Tenstorrent': random.uniform(0.0, 0.7),
'Dolcera': random.uniform(0.0, 0.7),
'A Lam': random.uniform(0.0, 0.7),
'SEDEMAC': random.uniform(0.0, 0.7),
'INSTRUMENTS': random.uniform(0.0, 0.7),
'NXP Semiconductors': random.uniform(0.0, 0.7),
'STMicroelectronics': random.uniform(0.0, 0.7),
'Texas Instruments': random.uniform(0.0, 0.7),
'Panasonic': random.uniform(0.0, 0.7)

    },
    'Civil Engineering': {
        'ARUP': random.uniform(0.0, 0.7),
'ARCADIS': random.uniform(0.0, 0.7),
'ATKINS': random.uniform(0.0, 0.7),
'Force': random.uniform(0.0, 0.7),
'Greenko Jacobs': random.uniform(0.0, 0.7),
'Stantec': random.uniform(0.0, 0.7),
'Thornton Tomasetti': random.uniform(0.0, 0.7),
'AMARARALA': random.uniform(0.0, 0.7),
'Assystem Stup': random.uniform(0.0, 0.7),
'LISEN A TOLERO': random.uniform(0.0, 0.7),
'RAMBOLL': random.uniform(0.0, 0.7),
'TATA': random.uniform(0.0, 0.7),
'IcoNS': random.uniform(0.0, 0.7),
'Bechtel Corporation': random.uniform(0.0, 0.7),
'AECOM': random.uniform(0.0, 0.7),
'Jacobs Engineering Group': random.uniform(0.0, 0.7),
'WSP Global': random.uniform(0.0, 0.7),
'Kiewit Corporation': random.uniform(0.0, 0.7),
'Mott MacDonald': random.uniform(0.0, 0.7),
'Balfour Beatty': random.uniform(0.0, 0.7),
'Parsons Corporation': random.uniform(0.0, 0.7),
'Leighton Holdings': random.uniform(0.0, 0.7),
'Obayashi Corporation': random.uniform(0.0, 0.7),
'Gammon Construction': random.uniform(0.0, 0.7),
'Skidmore, Owings & Merrill (SOM)': random.uniform(0.0, 0.7),
'Daelim Industrial Co., Ltd.': random.uniform(0.0, 0.7),
'Hill International': random.uniform(0.0, 0.7),
'The Walsh Group': random.uniform(0.0, 0.7),
'COWI': random.uniform(0.0, 0.7),
'Orascom Construction': random.uniform(0.0, 0.7),
'Dragados': random.uniform(0.0, 0.7),
'Acciona': random.uniform(0.0, 0.7),
'J. Murphy & Sons': random.uniform(0.0, 0.7)
    },
    'Pharmacy': {
       'Aragen': random.uniform(0.0, 0.7),
'Cipla': random.uniform(0.0, 0.7),
'kmk': random.uniform(0.0, 0.7),
'ADITYA BIRLA': random.uniform(0.0, 0.7),
'Aizant': random.uniform(0.0, 0.7),
'Biocon Biologics': random.uniform(0.0, 0.7),
'Elucidata': random.uniform(0.0, 0.7),
'freyr': random.uniform(0.0, 0.7),
'FRESENIUS': random.uniform(0.0, 0.7),
'КАВІ': random.uniform(0.0, 0.7),
'DataZymes': random.uniform(0.0, 0.7),
'Pfizer': random.uniform(0.0, 0.7),
'Strand': random.uniform(0.0, 0.7),
'PEISION MEDICINE SOLUTIONS': random.uniform(0.0, 0.7),
'SII': random.uniform(0.0, 0.7),
'Zydus': random.uniform(0.0, 0.7),
'Sun Pharmaceutical Industries': random.uniform(0.0, 0.7),
'Dr. Reddys Laboratories': random.uniform(0.0, 0.7),
'Lupin Limited': random.uniform(0.0, 0.7),
'Cipla': random.uniform(0.0, 0.7),
'Biocon': random.uniform(0.0, 0.7),
'Cadila Healthcare': random.uniform(0.0, 0.7),
'Glenmark Pharmaceuticals': random.uniform(0.0, 0.7),
'Torrent Pharmaceuticals': random.uniform(0.0, 0.7),
'Divis Laboratories': random.uniform(0.0, 0.7),
'Alembic Pharmaceuticals': random.uniform(0.0, 0.7),
'Ipca Laboratories': random.uniform(0.0, 0.7),
'Wockhardt': random.uniform(0.0, 0.7),
'Alkem Laboratories': random.uniform(0.0, 0.7),
'Natco Pharma': random.uniform(0.0, 0.7),
'Granules India': random.uniform(0.0, 0.7),
'Aurobindo Pharma': random.uniform(0.0, 0.7),
'Emcure Pharmaceuticals': random.uniform(0.0, 0.7),
'Zydus Cadila': random.uniform(0.0, 0.7),
'Abbott Laboratories': random.uniform(0.0, 0.7),
'Novartis': random.uniform(0.0, 0.7),
'GSK Pharmaceuticals': random.uniform(0.0, 0.7),
'AstraZeneca': random.uniform(0.0, 0.7)
    }
,
    'Chemical Engineering': {
    'ExxonMobil': random.uniform(0.0, 0.7),
'Chevron': random.uniform(0.0, 0.7),
'Shell': random.uniform(0.0, 0.7),
'Dow': random.uniform(0.0, 0.7),
'BASF': random.uniform(0.0, 0.7),
'Procter & Gamble': random.uniform(0.0, 0.7),
'DuPont': random.uniform(0.0, 0.7),
'Linde': random.uniform(0.0, 0.7),
'SABIC': random.uniform(0.0, 0.7),
'Honeywell UOP': random.uniform(0.0, 0.7),
'Eastman Chemical Company': random.uniform(0.0, 0.7),
'INEOS': random.uniform(0.0, 0.7),
'LyondellBasell': random.uniform(0.0, 0.7),
'Air Liquide': random.uniform(0.0, 0.7),
'Monsanto': random.uniform(0.0, 0.7),
'GSK': random.uniform(0.0, 0.7),
'Novozymes': random.uniform(0.0, 0.7),
'Bayer': random.uniform(0.0, 0.7),
'Pfizer': random.uniform(0.0, 0.7),
'Merck': random.uniform(0.0, 0.7),
'Johnson Matthey': random.uniform(0.0, 0.7),
'Syngenta': random.uniform(0.0, 0.7),
'AkzoNobel': random.uniform(0.0, 0.7),
'PPG Industries': random.uniform(0.0, 0.7),
'Covestro': random.uniform(0.0, 0.7),
'3M': random.uniform(0.0, 0.7),
'ADM (Archer Daniels Midland)': random.uniform(0.0, 0.7),
'Evonik Industries': random.uniform(0.0, 0.7),
'Baker Hughes': random.uniform(0.0, 0.7),
'KBR, Inc.': random.uniform(0.0, 0.7),
'Wood Group': random.uniform(0.0, 0.7),
'Mitsubishi Chemical Corporation': random.uniform(0.0, 0.7),
'Solvay': random.uniform(0.0, 0.7),
'Lanxess': random.uniform(0.0, 0.7),
'Occidental Petroleum Corporation (OxyChem)': random.uniform(0.0, 0.7),
'Praxair': random.uniform(0.0, 0.7)

}
,
    'Economics and Finanace': {
    'Genpact': random.uniform(0.0, 0.7),
'Accenture': random.uniform(0.0, 0.7),
'Deloitte': random.uniform(0.0, 0.7),
'EY (Ernst & Young)': random.uniform(0.0, 0.7),
'KPMG': random.uniform(0.0, 0.7),
'McKinsey & Company': random.uniform(0.0, 0.7),
'Bain & Company': random.uniform(0.0, 0.7),
'Boston Consulting Group (BCG)': random.uniform(0.0, 0.7),
'Nomura': random.uniform(0.0, 0.7),
'Goldman Sachs': random.uniform(0.0, 0.7),
'JP Morgan': random.uniform(0.0, 0.7),
'Morgan Stanley': random.uniform(0.0, 0.7),
'Barclays': random.uniform(0.0, 0.7),
'UBS': random.uniform(0.0, 0.7),
'Credit Suisse': random.uniform(0.0, 0.7),
'Nomura': random.uniform(0.0, 0.7),
'BlackRock': random.uniform(0.0, 0.7),
'Fidelity International': random.uniform(0.0, 0.7),
'Citi': random.uniform(0.0, 0.7),
'Wells Fargo': random.uniform(0.0, 0.7),
'BNP Paribas': random.uniform(0.0, 0.7),
'Deutsche Bank': random.uniform(0.0, 0.7),
'HSBC': random.uniform(0.0, 0.7),
'Standard Chartered': random.uniform(0.0, 0.7),
'American Express': random.uniform(0.0, 0.7),
'Moodys Analytics': random.uniform(0.0, 0.7),
'S&P Global': random.uniform(0.0, 0.7),
'Morningstar': random.uniform(0.0, 0.7),
'FactSet': random.uniform(0.0, 0.7),
'Thomson Reuters': random.uniform(0.0, 0.7),
'MSCI': random.uniform(0.0, 0.7),
'Capital IQ': random.uniform(0.0, 0.7),
'CRISIL': random.uniform(0.0, 0.7),
'IHS Markit': random.uniform(0.0, 0.7),
'Fitch Ratings': random.uniform(0.0, 0.7),
'Moodys Investors Service': random.uniform(0.0, 0.7)
}
,
    'Humanities and Social Sciences': {
    'Google': random.uniform(0.0, 0.7),
'Microsoft': random.uniform(0.0, 0.7),
'IBM': random.uniform(0.0, 0.7),
'Deloitte': random.uniform(0.0, 0.7),
'EY (Ernst & Young)': random.uniform(0.0, 0.7),
'Accenture': random.uniform(0.0, 0.7),
'Wipro': random.uniform(0.0, 0.7),
'Tata Consultancy Services (TCS)': random.uniform(0.0, 0.7),
'Infosys': random.uniform(0.0, 0.7),
'Hindustan Unilever Limited (HUL)': random.uniform(0.0, 0.7),
'Procter & Gamble': random.uniform(0.0, 0.7),
'Amazon': random.uniform(0.0, 0.7),
'Flipkart': random.uniform(0.0, 0.7),
'Reliance Industries': random.uniform(0.0, 0.7),
'Genpact': random.uniform(0.0, 0.7),
'American Express': random.uniform(0.0, 0.7),
'McKinsey & Company': random.uniform(0.0, 0.7),
'Bain & Company': random.uniform(0.0, 0.7),
'Boston Consulting Group (BCG)': random.uniform(0.0, 0.7),
'Aditya Birla Group': random.uniform(0.0, 0.7),
'HCL Technologies': random.uniform(0.0, 0.7),
'Cognizant': random.uniform(0.0, 0.7),
'KPMG': random.uniform(0.0, 0.7),
'Capgemini': random.uniform(0.0, 0.7),
'Infosys BPM': random.uniform(0.0, 0.7),
'WNS Global Services': random.uniform(0.0, 0.7),
'Tata Steel': random.uniform(0.0, 0.7),
'ITC Limited': random.uniform(0.0, 0.7),
'ICICI Bank': random.uniform(0.0, 0.7),
'State Bank of India (SBI)': random.uniform(0.0, 0.7),
'Axis Bank': random.uniform(0.0, 0.7),
'HDFC Bank': random.uniform(0.0, 0.7)

}
,
    'Chemisty': {'ExxonMobil': random.uniform(0.0, 0.7),
    'Chevron': random.uniform(0.0, 0.7),
'Shell': random.uniform(0.0, 0.7),
'Dow': random.uniform(0.0, 0.7),
'BASF': random.uniform(0.0, 0.7),
'Procter & Gamble': random.uniform(0.0, 0.7),
'DuPont': random.uniform(0.0, 0.7),
'Linde': random.uniform(0.0, 0.7),
'SABIC': random.uniform(0.0, 0.7),
'Honeywell UOP': random.uniform(0.0, 0.7),
'Eastman Chemical Company': random.uniform(0.0, 0.7),
'Aragen': random.uniform(0.0, 0.7),
'Cipla': random.uniform(0.0, 0.7),
'kmk': random.uniform(0.0, 0.7),
'ADITYA BIRLA': random.uniform(0.0, 0.7),
'Aizant': random.uniform(0.0, 0.7),
'Biocon Biologics': random.uniform(0.0, 0.7),
'Elucidata': random.uniform(0.0, 0.7),
'freyr': random.uniform(0.0, 0.7),
'FRESENIUS': random.uniform(0.0, 0.7),
'КАВІ': random.uniform(0.0, 0.7),
'DataZymes': random.uniform(0.0, 0.7),
'Sun Pharmaceutical Industries': random.uniform(0.0, 0.7)
}
}


def assign_placement(course):
    if random.uniform(0.0, 1.0) < 0.8: 
        return random.choices(list(placement_companies[course].keys()), 
                              weights=placement_companies[course].values())[0]
    else:
        return 'Unplaced'

fourth_year_students['Placement'] = fourth_year_students['Course'].apply(assign_placement)


alumni_data_path = './Alumni_Data/alumni_data_2023.csv' #change the year in the file name as required
fourth_year_students.to_csv(alumni_data_path, index=False)

print(f'Alumni data with ratios and some students without placement has been generated and saved to {alumni_data_path}')

# %% [markdown]
# # Data Preparation

# %%
#imports
import random
import pandas as pd
import os
import seaborn as sns
import numpy as np

# %%
def load_csvs_into_list(folder_path, file_pattern="alumni_data_*\.csv"):
    """
    Load all CSV files in a folder into a list of dataframes.

    Parameters:
    - folder_path (str): The path to the folder containing CSV files.
    - file_pattern (str): The pattern to match CSV file names.

    Returns:
    - List of pandas DataFrames.
    """
    dataframes = []

    # Iterate through files in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith(".csv") and filename.startswith("alumni_data_"):
            file_path = os.path.join(folder_path, filename)

            # Extract year from the filename
            year = filename.split("_")[2].split(".")[0]

            # Read CSV into a dataframe and append to the list
            df = pd.read_csv(file_path)
            df['Year'] = year  # Adding a 'Year' column to the dataframe
            dataframes.append(df)

    return dataframes

# %%
folder_path = "./Alumni_Data/"
dataframes_list = load_csvs_into_list(folder_path)

# Access individual dataframes in the list
for idx, df in enumerate(dataframes_list):
    print(f"Dataframe {idx + 1} - Year: {df['Year'].unique()[0]}")
    print(df.head())
    print("\n")
# Out:
# Dataframe 1 - Year: 2017
#    Student ID                  Course   Degree  CGPA  Year           Placement
# 0  2017A0003A             Mathematics      B.E  6.48  2017            Flipkart
# 1  2017A0005A     Biological Sciences      B.E  6.13  2017   Ipca Laboratories
# 2  2017P0007P       Civil Engineering  B.Pharm  9.61  2017            Unplaced
# 3  2017D0017D    Chemical Engineering     Ph.D  6.36  2017        Baker Hughes
# 4  2017A0021A  Economics and Finanace      B.E  5.74  2017  EY (Ernst & Young)
#
#
# Dataframe 2 - Year: 2023
#    Student ID                                    Course   Degree  CGPA  Year  \
# 0  2023P0007P                                  Chemisty  B.Pharm  7.70  2023
# 1  2023D0008D                         Civil Engineering     Ph.D  6.39  2023
# 2  2023H0009H  Computer Science and Information Systems      M.E  6.95  2023
# 3  2023H0027H                               Mathematics      M.E  8.71  2023
# ...

# %%
# Concatenate all dataframes into a single dataframe
combined_alumni_data = pd.concat(dataframes_list, ignore_index=True)
combined_alumni_data
# Out:
#         Student ID                                    Course   Degree  CGPA  \
# 0       2017A0003A                               Mathematics      B.E  6.48
# 1       2017A0005A                       Biological Sciences      B.E  6.13
# 2       2017P0007P                         Civil Engineering  B.Pharm  9.61
# 3       2017D0017D                      Chemical Engineering     Ph.D  6.36
# 4       2017A0021A                    Economics and Finanace      B.E  5.74
# ...            ...                                       ...      ...   ...
# 30949  2021A11157A            Humanities and Social Sciences      B.E  5.84
# 30950  2021A11162A                    Economics and Finanace      B.E  5.32
# 30951  2021A11168A  Computer Science and Information Systems      B.E  6.94
# 30952  2021D11170D    Electrical and Electronics Engineering     Ph.D  5.18
# 30953  2021A11171A            Humanities and Social Sciences      B.E  5.71
#
#        Year                 Placement
# ...

# %%
combined_alumni_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30954 entries, 0 to 30953
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student ID  30954 non-null  object
#  1   Course      30954 non-null  object
#  2   Degree      30954 non-null  object
#  3   CGPA        30954 non-null  float64
#  4   Year        30954 non-null  object
#  5   Placement   30954 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 1.4+ MB

# %%
companies_list = list(combined_alumni_data['Placement'].unique())

# %%
companies_list
# Out:
# ['Flipkart',
#  'Ipca Laboratories',
#  'Unplaced',
#  'Baker Hughes',
#  'EY (Ernst & Young)',
#  'STMicroelectronics',
#  'Praxair',
#  'Siemens',
#  'onsemi',
#  'INSTRUMENTS',
#  'Ricoh',
#  'Micron',
#  'КАВІ',
#  'Teradata',
#  'Reliance Industries',
#  'JK Fenner',
#  'Pfizer',
#  'AstraZeneca',
#  'freyr',
#  'Microsoft',
#  'CRISIL',
#  'GSK',
#  'DataZymes',
#  'Infosys BPM',
#  'Dell',
#  'Mercedes Benz',
#  'CONCR',
#  'SABIC',
#  'Zydus',
#  'Wood Group',
#  'Chevron',
#  'ADITYA BIRLA',
#  'Biocon',
#  'IcoNS',
#  'Google',
#  'Wells Fargo',
#  'TATA',
#  'Linde',
#  'proteanTecs',
#  'The Walsh Group',
#  'Boston Consulting Group (BCG)',
#  'State Bank of India (SBI)',
#  'Honeywell',
#  'Sun Pharmaceutical Industries',
#  'Cummins Inc.',
#  'RAMBOLL',
#  'Microsemi',
#  'ExxonMobil',
#  'Tata Steel',
#  'Infosys',
#  'HCL Technologies',
#  'Nomura',
#  'Fidelity International',
#  'Wabtec',
#  'Lime',
#  'Qualcomm',
#  'ARM',
#  'Skidmore, Owings & Merrill (SOM)',
# ...

# %%
len(companies_list)
# Out:
# 252

# %%
company_counts_per_year = combined_alumni_data.groupby(['Year', 'Placement']).size().unstack(fill_value=0)
company_counts_per_year
# Out:
# Placement  3M  3SC  A Lam  ABB  ADITYA BIRLA  ADM (Archer Daniels Midland)  \
# Year
# 2008        3    0      1    0             1                             2
# 2009        2    0      2    2             2                             3
# 2010        6    1      1    0             5                             0
# 2011        2    1      6    0             5                             4
# 2012        2    9      5    8             7                             0
# 2013        7    4      2    7             4                             1
# 2014        4    7      7    2            19                             2
# 2015        3    7      2    4             5                             3
# 2016        5    3      0    4            11                             3
# 2017        2    1     13    0            17                             3
# 2018        2    2     11    7             5                             0
# ...

# %%
# Calculate counts of placed and unplaced students per year
placed_counts = company_counts_per_year.drop(columns=['Unplaced'], errors='ignore').sum(axis=1).rename('Placed')
unplaced_counts = company_counts_per_year['Unplaced'].rename('Unplaced')

# %%
company_counts_per_year.index = pd.to_numeric(company_counts_per_year.index)

# %%
company_counts_per_year
# Out:
# Placement  3M  3SC  A Lam  ABB  ADITYA BIRLA  ADM (Archer Daniels Midland)  \
# Year
# 2008        3    0      1    0             1                             2
# 2009        2    0      2    2             2                             3
# 2010        6    1      1    0             5                             0
# 2011        2    1      6    0             5                             4
# 2012        2    9      5    8             7                             0
# 2013        7    4      2    7             4                             1
# 2014        4    7      7    2            19                             2
# 2015        3    7      2    4             5                             3
# 2016        5    3      0    4            11                             3
# 2017        2    1     13    0            17                             3
# 2018        2    2     11    7             5                             0
# ...

# %%
company_counts_per_year_per_course = combined_alumni_data.groupby(['Year', 'Course', 'Placement']).size().unstack(fill_value=0)
company_counts_per_year_per_course
# Out:
# Placement                                      3M  3SC  A Lam  ABB  \
# Year Course
# 2008 Biological Sciences                        0    0      0    0
#      Chemical Engineering                       3    0      0    0
#      Chemisty                                   0    0      0    0
#      Civil Engineering                          0    0      0    0
#      Computer Science and Information Systems   0    0      0    0
# ...                                            ..  ...    ...  ...
# 2023 Humanities and Social Sciences             0    0      0    0
#      Mathematics                                0    0      0    0
#      Mechanical Engineering                     0    8      0    3
#      Pharmacy                                   0    0      0    0
#      Physics                                    0    0     12    0
#
# Placement                                      ADITYA BIRLA  \
# Year Course
# 2008 Biological Sciences                                  0
# ...

# %%
# Calculate counts of placed and unplaced students per year and course
placed_counts_per_course = company_counts_per_year_per_course.drop(columns=['Unplaced'], errors='ignore').sum(axis=1).rename('Placed')
unplaced_counts_per_course = company_counts_per_year_per_course['Unplaced'].rename('Unplaced')

# %%
# Combine placed and unplaced counts based on 'Year' and 'Course'
combined_counts_per_course = pd.merge(placed_counts_per_course, unplaced_counts_per_course, left_index=True, right_index=True)
combined_counts_per_course
# Out:
#                                                Placed  Unplaced
# Year Course
# 2008 Biological Sciences                           34         6
#      Chemical Engineering                          51         9
#      Chemisty                                      40        10
#      Civil Engineering                             28        10
#      Computer Science and Information Systems      35         6
# ...                                               ...       ...
# 2023 Humanities and Social Sciences               207        52
#      Mathematics                                  185        36
#      Mechanical Engineering                       210        63
#      Pharmacy                                     246        58
#      Physics                                      186        48
#
# [192 rows x 2 columns]

# %%
# Define CGPA ranges
cgpa_ranges = [5, 6, 7, 8, 9, 10]

# Create a new column 'CGPA Range' based on CGPA ranges
combined_alumni_data['CGPA Range'] = pd.cut(combined_alumni_data['CGPA'], bins=cgpa_ranges, right=False)
combined_alumni_data['CGPA Range'] = combined_alumni_data['CGPA Range'].astype(str)
combined_alumni_data['CGPA Range'] = combined_alumni_data['CGPA Range'].replace('[9, 10)','[9, 10]')

# Update CGPA Range for students with CGPA 10 to [9, 10]
combined_alumni_data.loc[combined_alumni_data['CGPA'] == 10, 'CGPA Range'] = '[9, 10]'

combined_alumni_data
# Out:
#         Student ID                                    Course   Degree  CGPA  \
# 0       2017A0003A                               Mathematics      B.E  6.48
# 1       2017A0005A                       Biological Sciences      B.E  6.13
# 2       2017P0007P                         Civil Engineering  B.Pharm  9.61
# 3       2017D0017D                      Chemical Engineering     Ph.D  6.36
# 4       2017A0021A                    Economics and Finanace      B.E  5.74
# ...            ...                                       ...      ...   ...
# 30949  2021A11157A            Humanities and Social Sciences      B.E  5.84
# 30950  2021A11162A                    Economics and Finanace      B.E  5.32
# 30951  2021A11168A  Computer Science and Information Systems      B.E  6.94
# 30952  2021D11170D    Electrical and Electronics Engineering     Ph.D  5.18
# 30953  2021A11171A            Humanities and Social Sciences      B.E  5.71
#
#        Year                 Placement CGPA Range
# ...

# %%
combined_alumni_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30954 entries, 0 to 30953
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student ID  30954 non-null  object
#  1   Course      30954 non-null  object
#  2   Degree      30954 non-null  object
#  3   CGPA        30954 non-null  float64
#  4   Year        30954 non-null  object
#  5   Placement   30954 non-null  object
#  6   CGPA Range  30954 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 1.7+ MB

# %%
# Count occurrences of each company per CGPA range and placement
company_counts_per_year_cgpa_range = combined_alumni_data.groupby(['Year', 'CGPA Range', 'Placement']).size().unstack(fill_value=0)
company_counts_per_year_cgpa_range
# Out:
# Placement        3M  3SC  A Lam  ABB  ADITYA BIRLA  \
# Year CGPA Range
# 2008 [5, 6)       0    0      0    0             0
#      [6, 7)       2    0      0    0             0
#      [7, 8)       0    0      1    0             0
#      [8, 9)       0    0      0    0             0
#      [9, 10]      1    0      0    0             1
# ...              ..  ...    ...  ...           ...
# 2023 [5, 6)       3    3      6    0             1
#      [6, 7)       2    3      3    1             3
#      [7, 8)       3    1      2    1             4
#      [8, 9)       1    0      0    1             4
#      [9, 10]      3    1      1    0             3
#
# Placement        ADM (Archer Daniels Midland)  AECOM  AMARARALA  AMD  AMDET  \
# Year CGPA Range
# 2008 [5, 6)                                 1      1          0    2      0
#      [6, 7)                                 0      0          0    1      1
#      [7, 8)                                 0      1          0    0      2
# ...

# %%
# Calculate counts of placed and unplaced students per CGPA range
placed_counts_per_cgpa_range = company_counts_per_year_cgpa_range.drop(columns=['Unplaced'], errors='ignore').sum(axis=1).rename('Placed')
unplaced_counts_per_cgpa_range = company_counts_per_year_cgpa_range['Unplaced'].rename('Unplaced')

# Combine placed and unplaced counts based on 'CGPA Range'
combined_counts_per_cgpa_range = pd.merge(placed_counts_per_cgpa_range, unplaced_counts_per_cgpa_range, left_index=True, right_index=True)
combined_counts_per_cgpa_range
# Out:
#                  Placed  Unplaced
# Year CGPA Range
# 2008 [5, 6)          96        19
#      [6, 7)          90        25
#      [7, 8)          87        21
#      [8, 9)          82        24
#      [9, 10]         82        22
# ...                 ...       ...
# 2023 [5, 6)         491       124
#      [6, 7)         524       146
#      [7, 8)         503       121
#      [8, 9)         494       130
#      [9, 10]        504       135
#
# [80 rows x 2 columns]

# %%
# Filter Placed and Unplaced data
placed_data = combined_alumni_data[combined_alumni_data['Placement'] != 'Unplaced']
unplaced_data = combined_alumni_data[combined_alumni_data['Placement'] == 'Unplaced']

# %%
# Calculate average CGPA per year for Placed
average_cgpa_per_year_placed = placed_data.groupby('Year')['CGPA'].mean().reset_index()
average_cgpa_per_year_placed['Placement'] = 'Placed'
average_cgpa_per_year_placed
# Out:
#     Year      CGPA Placement
# 0   2008  7.421396    Placed
# 1   2009  7.438654    Placed
# 2   2010  7.435101    Placed
# 3   2011  7.476288    Placed
# 4   2012  7.496220    Placed
# 5   2013  7.420461    Placed
# 6   2014  7.446440    Placed
# 7   2015  7.427630    Placed
# 8   2016  7.503105    Placed
# 9   2017  7.469717    Placed
# 10  2018  7.505799    Placed
# 11  2019  7.498400    Placed
# 12  2020  7.495019    Placed
# 13  2021  7.482854    Placed
# 14  2022  7.512680    Placed
# 15  2023  7.484090    Placed

# %%
# Calculate average CGPA per year for Unplaced
average_cgpa_per_year_unplaced = unplaced_data.groupby('Year')['CGPA'].mean().reset_index()
average_cgpa_per_year_unplaced['Placement'] = 'Unplaced'
average_cgpa_per_year_unplaced
# Out:
#     Year      CGPA Placement
# 0   2008  7.507387  Unplaced
# 1   2009  7.405893  Unplaced
# 2   2010  7.445000  Unplaced
# 3   2011  7.342605  Unplaced
# 4   2012  7.416702  Unplaced
# 5   2013  7.570313  Unplaced
# 6   2014  7.460000  Unplaced
# 7   2015  7.522190  Unplaced
# 8   2016  7.441380  Unplaced
# 9   2017  7.438023  Unplaced
# 10  2018  7.442213  Unplaced
# 11  2019  7.472742  Unplaced
# 12  2020  7.505930  Unplaced
# 13  2021  7.509186  Unplaced
# 14  2022  7.533447  Unplaced
# 15  2023  7.504771  Unplaced

# %%
# Concatenate the DataFrames
average_cgpa_per_year = pd.concat([average_cgpa_per_year_placed, average_cgpa_per_year_unplaced], ignore_index=True)

# %% [markdown]
# # Data Visualization

# %%
import matplotlib.pyplot as plt
import plotly.express as px

# %%
# Create a multiline graph using Plotly
fig = px.line(x=placed_counts.index, y=[placed_counts, unplaced_counts], labels={'y':'Count', 'x':'Year'},
              title='Placement Status Over the Years', line_shape='linear',
              line_dash_sequence=['solid', 'solid'],
              color_discrete_sequence=['blue', 'red'])

fig.update_layout(
    xaxis_title='Year',
    yaxis_title='Count',
    legend_title='Placement Status',
)

fig.for_each_trace(lambda t: t.update(name=t.name.replace('wide_variable_0', 'Placed').replace('wide_variable_1', 'Unplaced')))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Static Image of Plotly plot

# %%
def placement_stats_per_year(df, year):
    # Filter the DataFrame for the selected year
    selected_year_counts = df.loc[year]

    # Exclude 'Unplaced' and select top 10 companies
    top_10_companies = selected_year_counts[selected_year_counts.index != 'Unplaced'].nlargest(10)
    top_10_companies = top_10_companies.iloc[::-1]

    # Create a horizontal bar plot using Plotly Express
    fig = px.bar(top_10_companies, orientation='h', labels={'y': 'Company', 'x': 'Count'},
                title=f'Top 10 Placement Status for {year}',
                 color=top_10_companies.index.to_list(),
                 )

    fig.update_layout(
        xaxis_title='Count',
        yaxis_title='Company',
    )

    fig.show()

# %%
for yr in company_counts_per_year.index.to_list():
    placement_stats_per_year(company_counts_per_year, yr)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# One of the Static images for plotly graph

# %%
def placement_stats_per_year_per_course(df, year):

    filtered_counts_per_course = df.loc[year]
    placed = filtered_counts_per_course['Placed']
    unplaced = filtered_counts_per_course['Unplaced']
    # Create a horizontal stacked bar plot using Plotly Express
    fig = px.bar(filtered_counts_per_course, orientation='h',x=[placed, unplaced], y=filtered_counts_per_course.index,
                title=f'Placement Status for Year {year} per Course',
                color_discrete_sequence=['blue', 'red'], barmode='stack',)

    fig.update_layout(
        xaxis_title='Count',
        yaxis_title='Course',
        legend_title='Placement Status',
    )

    fig.show()

# %%
for yr in company_counts_per_year.index.to_list():
    placement_stats_per_year_per_course(combined_counts_per_course, str(yr))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# One of the Static images for plotly graph

# %%
def placement_stats_per_year_per_cgpa_range(df, year):

    filtered_counts_per_cgpa = df.loc[year]
    placed = filtered_counts_per_cgpa['Placed']
    unplaced = filtered_counts_per_cgpa['Unplaced']

    # Create a horizontal stacked bar plot using Plotly Express
    fig = px.bar(combined_counts_per_cgpa_range, x=[placed, unplaced], y=filtered_counts_per_cgpa.index,
                title=f'Placement Status for Year {year} per CGPA Range',
                color_discrete_sequence=['blue', 'red'], barmode='stack')

    fig.update_layout(
        xaxis_title='Count',
        yaxis_title='CGPA Range',
        xaxis=dict(tickvals=[0, 1]),
        legend_title='Placement Status',
    )

    fig.for_each_trace(lambda t: t.update(name=t.name.replace('wide_variable_0', 'Placed').replace('wide_variable_1', 'Unplaced')))

    fig.show()

# %%
for yr in company_counts_per_year.index.to_list():
    placement_stats_per_year_per_cgpa_range(combined_counts_per_cgpa_range, str(yr))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# One of the Static images for plotly graph

# %%
# Create a multiline plot using Plotly Express
fig = px.line(average_cgpa_per_year, x='Year', y='CGPA', color='Placement',
              title='Average CGPA for Placed and Unplaced Students Over the Years',
              labels={'CGPA': 'Average CGPA', 'Year': 'Year', 'Placement': 'Placement'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Static image for plotly graph
